# %% [markdown]
# ## ML Model _______

# %% [markdown]
# ### Datasource
#     1. https://www.kaggle.com/uciml/breast-cancer-wisconsin-data

# %% [markdown]
# ### Objective
#     1. Uncover the factors that lead to employee attrition.

# %% [markdown]
# ### Target
#     1. Difference between Train - Test Accuracy < 5%
#     2. Test Accuracy >= 90%
#     3. Recall >= 90%

# %% [markdown]
# ### Pre-Processing

# %% [markdown]
# #### Libraries

# %%
import sys
import os

import warnings
warnings.filterwarnings("ignore")

import numpy as np

import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")
plt.rcParams['figure.figsize'] = [12, 10]

import seaborn as sns

import pandas as pd
pd.set_option('display.max_columns', 100)
pd.set_option('max_colwidth', -1)

from tabulate import tabulate
tabulate.PRESERVE_WHITESPACE = False

from scipy import stats

# --------------- sklearn libraries ---------------------

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

from sklearn import preprocessing
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import StackingClassifier
from sklearn import svm
from sklearn.neural_network import MLPClassifier

# --------------- End of sklearn libraries ---------------------

import catboost as cb

import shap

# %% [markdown]
# #### Global Constants

# %%
RND_STATE = 39  # random_state where used is assigned RND_STATE
TESTSIZE = 0.15  # test_size where used is assigned TESTSIZE

scoremet = ['f1'] # Specify the scoring metrics to be used in Hyperparameter Tuning
scoremet_cbc = ['F1'] # CatBoost module nomenclature changes. Watchout.

# %%
nscores = len(scoremet)
nscores_cbc = len(scoremet_cbc)

if (nscores == 0) or (nscores_cbc == 0):
    scoremet = ['f1'] # Default evaluation metrics for Scikit ML Models
    scoremet_cbc = ['F1'] # # Default evaluation metrics for CatBoost Classifier
if nscores > 1 or nscores_cbc > 1:
    sys.exit("Only ONE Evaluation Metric Allowed")

# %% [markdown]
# #### I/O Path & File Name

# %%
PATH = r"C:\DSML_Case_Studies\01_Classification\01_Dataset"
OUTPATH = r"C:\DSML_Case_Studies\01_Classification\03_Output"
DATASET = r"\Dataset_IBM_Attrition_34x1.csv"
PREFIX = r"\MLM_V2.2_IBM_Attrition_Iteration_1_"

# Specify number of features and targets

n_features = 30
n_target = 1

# %% [markdown]
# #### Dataframe Construction

# %%
# Dataframe Definition & Classifying Features & Targets

df = pd.read_csv(f"{PATH}{DATASET}")
df = df.round(decimals=3)

dropcol = ['DailyRate', 'EmployeeCount', 'EmployeeNumber', 'Over18', 'StandardHours']
df = df.drop(columns=dropcol)

collst = []
for columns in df.columns:
    collst.append(columns)

featlst = collst[0:len(collst)-n_target]
targlst = collst[-n_target:]

cat_df = df.select_dtypes(include=['object'])
catlst = []
for col in cat_df.columns:
    catlst.append(col)

y_catlst = [value for value in catlst if value in targlst]

# %% [markdown]
# #### Encoding

# %%
print("Dataframe BEFORE Encoding: ")
# Out:
# Dataframe BEFORE Encoding:

# %%
df.head()
# Out:
#    Age     BusinessTravel              Department  DistanceFromHome  \
# 0  41   Travel_Rarely      Sales                   1
# 1  49   Travel_Frequently  Research & Development  8
# 2  37   Travel_Rarely      Research & Development  2
# 3  33   Travel_Frequently  Research & Development  3
# 4  27   Travel_Rarely      Research & Development  2
#
#    Education EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0  2          Life Sciences  2                        Female  94
# 1  1          Life Sciences  3                        Male    61
# 2  2          Other          4                        Male    92
# 3  4          Life Sciences  4                        Female  56
# 4  1          Medical        1                        Male    40
#
#    JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# 0  3               2         Sales Executive        4
# 1  2               2         Research Scientist     2
# 2  2               1         Laboratory Technician  3
# 3  3               1         Research Scientist     3
# 4  3               1         Laboratory Technician  2
#
#   MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked OverTime  \
# 0  Single        5993           19479        8                   Yes
# 1  Married       5130           24907        1                   No
# 2  Single        2090           2396         6                   Yes
# 3  Married       2909           23159        1                   Yes
# 4  Married       3468           16632        9                   No
#
#    PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0  11                 3                  1
# 1  23                 4                  4
# 2  15                 3                  2
# 3  11                 3                  3
# 4  12                 3                  4
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0  0                 8                  0
# 1  1                 10                 3
# 2  0                 7                  3
# 3  0                 8                  3
# 4  1                 6                  3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0  1                6               4
# 1  3                10              7
# 2  3                0               0
# 3  3                8               7
# 4  3                2               2
#
#    YearsSinceLastPromotion  YearsWithCurrManager Attrition
# 0  0                        5                     Yes
# 1  1                        7                     No
# 2  0                        0                     Yes
# 3  3                        0                     No
# 4  2                        2                     No

# %%
# Encode Categorical Columns

for i in range(0, len(collst), 1):
    temp = df.dtypes[collst[i]]
    if temp == 'object':
        df[collst[i]] = df[collst[i]].astype('category')
        df[collst[i]] = df[collst[i]].cat.codes
    else:
        continue
        
# Features & Target DataFrame

X = df.drop(columns=targlst)
y = df.drop(columns=featlst)

# %%
print("Dataframe AFTER Encoding: ")
# Out:
# Dataframe AFTER Encoding:

# %%
df.head()
# Out:
#    Age  BusinessTravel  Department  DistanceFromHome  Education  \
# 0  41   2               2           1                 2
# 1  49   1               1           8                 1
# 2  37   2               1           2                 2
# 3  33   1               1           3                 4
# 4  27   2               1           2                 1
#
#    EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0  1               2                        0       94
# 1  1               3                        1       61
# 2  4               4                        1       92
# 3  1               4                        0       56
# 4  3               1                        1       40
#
#    JobInvolvement  JobLevel  JobRole  JobSatisfaction  MaritalStatus  \
# 0  3               2         7        4                2
# 1  2               2         6        2                1
# 2  2               1         2        3                2
# 3  3               1         6        3                1
# 4  3               1         2        2                1
#
#    MonthlyIncome  MonthlyRate  NumCompaniesWorked  OverTime  \
# 0  5993           19479        8                   1
# 1  5130           24907        1                   0
# 2  2090           2396         6                   1
# 3  2909           23159        1                   1
# 4  3468           16632        9                   0
#
#    PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0  11                 3                  1
# 1  23                 4                  4
# 2  15                 3                  2
# 3  11                 3                  3
# 4  12                 3                  4
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0  0                 8                  0
# 1  1                 10                 3
# 2  0                 7                  3
# 3  0                 8                  3
# 4  1                 6                  3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0  1                6               4
# 1  3                10              7
# 2  3                0               0
# 3  3                8               7
# 4  3                2               2
#
#    YearsSinceLastPromotion  YearsWithCurrManager  Attrition
# 0  0                        5                     1
# 1  1                        7                     0
# 2  0                        0                     1
# 3  3                        0                     0
# 4  2                        2                     0

# %% [markdown]
# #### Imputing

# %%
print("Dataframe BEFORE Imputing: ")
# Out:
# Dataframe BEFORE Imputing:

# %%
print(df.isnull().sum(), end='\n\n')
# Out:
# Age                         0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# Attrition                   0
# dtype: int64

# %%
# Basic Imputing

''' Use Appropriate Imputer - Mean, Meadian, Mode... Others '''

df = df.apply(lambda x: x.fillna(x.median()), axis=0)

# %%
print("Dataframe AFTER MEDIAN Imputing: ")
# Out:
# Dataframe AFTER MEDIAN Imputing:

# %%
print(df.isnull().sum(), end='\n\n')
# Out:
# Age                         0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# Attrition                   0
# dtype: int64

# %% [markdown]
# #### Outlier Treatment

# %%
# """
#     1. Cell for removing outliers.
#     2. Based on Z-score.
# """
# df = df[(np.abs(stats.zscore(df)) < 3).all(axis=1)] # Removing the Outliers using Z-Scored Method

# %%
# Sanity checks before proceeding further

print("List of Features:", featlst, end='\n\n')
print("List of Targets:", targlst, end='\n\n')
print("List of Categorical Variables:", catlst, end='\n\n')
print("List of Categorical Targets", y_catlst, end='\n\n')
# Out:
# List of Features: ['Age', 'BusinessTravel', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
#
# List of Targets: ['Attrition']
#
# List of Categorical Variables: ['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime', 'Attrition']
#
# List of Categorical Targets ['Attrition']

# %% [markdown]
# #### Descriptive Stats

# %%
print("Descriptive Stats: ")
# Out:
# Descriptive Stats:

# %%
desc_stat = df.describe().T.round(3) # Univariate analyses
print(tabulate(desc_stat, headers=desc_stat.columns, tablefmt="github", numalign="right"))
# Out:
# |                          |   count |    mean |     std |   min |   25% |     50% |     75% |   max |
# |--------------------------|---------|---------|---------|-------|-------|---------|---------|-------|
# | Age                      |    1470 |  36.924 |   9.135 |    18 |    30 |      36 |      43 |    60 |
# | BusinessTravel           |    1470 |   1.607 |   0.665 |     0 |     1 |       2 |       2 |     2 |
# | Department               |    1470 |   1.261 |   0.528 |     0 |     1 |       1 |       2 |     2 |
# | DistanceFromHome         |    1470 |   9.193 |   8.107 |     1 |     2 |       7 |      14 |    29 |
# | Education                |    1470 |   2.913 |   1.024 |     1 |     2 |       3 |       4 |     5 |
# | EducationField           |    1470 |   2.248 |   1.331 |     0 |     1 |       2 |       3 |     5 |
# | EnvironmentSatisfaction  |    1470 |   2.722 |   1.093 |     1 |     2 |       3 |       4 |     4 |
# | Gender                   |    1470 |     0.6 |    0.49 |     0 |     0 |       1 |       1 |     1 |
# | HourlyRate               |    1470 |  65.891 |  20.329 |    30 |    48 |      66 |   83.75 |   100 |
# | JobInvolvement           |    1470 |    2.73 |   0.712 |     1 |     2 |       3 |       3 |     4 |
# | JobLevel                 |    1470 |   2.064 |   1.107 |     1 |     1 |       2 |       3 |     5 |
# | JobRole                  |    1470 |   4.459 |   2.462 |     0 |     2 |       5 |       7 |     8 |
# | JobSatisfaction          |    1470 |   2.729 |   1.103 |     1 |     2 |       3 |       4 |     4 |
# | MaritalStatus            |    1470 |   1.097 |    0.73 |     0 |     1 |       1 |       2 |     2 |
# | MonthlyIncome            |    1470 | 6502.93 | 4707.96 |  1009 |  2911 |    4919 |    8379 | 19999 |
# | MonthlyRate              |    1470 | 14313.1 | 7117.79 |  2094 |  8047 | 14235.5 | 20461.5 | 26999 |
# | NumCompaniesWorked       |    1470 |   2.693 |   2.498 |     0 |     1 |       2 |       4 |     9 |
# | OverTime                 |    1470 |   0.283 |   0.451 |     0 |     0 |       0 |       1 |     1 |
# | PercentSalaryHike        |    1470 |   15.21 |    3.66 |    11 |    12 |      14 |      18 |    25 |
# | PerformanceRating        |    1470 |   3.154 |   0.361 |     3 |     3 |       3 |       3 |     4 |
# | RelationshipSatisfaction |    1470 |   2.712 |   1.081 |     1 |     2 |       3 |       4 |     4 |
# | StockOptionLevel         |    1470 |   0.794 |   0.852 |     0 |     0 |       1 |       1 |     3 |
# | TotalWorkingYears        |    1470 |   11.28 |   7.781 |     0 |     6 |      10 |      15 |    40 |
# | TrainingTimesLastYear    |    1470 |   2.799 |   1.289 |     0 |     2 |       3 |       3 |     6 |
# | WorkLifeBalance          |    1470 |   2.761 |   0.706 |     1 |     2 |       3 |       3 |     4 |
# | YearsAtCompany           |    1470 |   7.008 |   6.127 |     0 |     3 |       5 |       9 |    40 |
# | YearsInCurrentRole       |    1470 |   4.229 |   3.623 |     0 |     2 |       3 |       7 |    18 |
# | YearsSinceLastPromotion  |    1470 |   2.188 |   3.222 |     0 |     0 |       1 |       3 |    15 |
# | YearsWithCurrManager     |    1470 |   4.123 |   3.568 |     0 |     2 |       3 |       7 |    17 |
# | Attrition                |    1470 |   0.161 |   0.368 |     0 |     0 |       0 |       0 |     1 |

# %% [markdown]
# #### Train-Test Split

# %%
# Train-Test Split

X = df.drop(columns=targlst)
y = df.drop(columns=featlst)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TESTSIZE, random_state=RND_STATE, stratify=y)

# %% [markdown]
# #### Random Over Sampling

# %%
# Over Sampling

from imblearn.over_sampling import RandomOverSampler

y_score = y_train.iloc[:, -1].value_counts()

print("Before Upsampling:", y_score)

ros = RandomOverSampler(random_state=RND_STATE)
X_train, y_train = ros.fit_resample(X_train, y_train)

y_score = y_train.iloc[:, -1].value_counts()

print("After Upsampling:", y_score)
# Out:
# Before Upsampling: 0    1048
# 1    201
# Name: Attrition, dtype: int64
# After Upsampling: 0    1048
# 1    1048
# Name: Attrition, dtype: int64

# %% [markdown]
# #### Random Under Sampling

# %%
# # Under Sampling

# from imblearn.under_sampling import RandomUnderSampler

# y_score = y_train.iloc[:, -1].value_counts()

# print("Before Downsampling:", y_score)

# rus = RandomUnderSampler(random_state=RND_STATE)
# X_train, y_train = rus.fit_resample(X_train, y_train)

# y_score = y_train.iloc[:, -1].value_counts()

# print("After Undersampling:", y_score)

# %%
print("Train Dataset - Features: ")
# Out:
# Train Dataset - Features:

# %%
X_train.head()
# Out:
#    Age  BusinessTravel  Department  DistanceFromHome  Education  \
# 0  47   2               2           2                 4
# 1  32   0               1           5                 4
# 2  31   0               1           1                 4
# 3  36   1               1           4                 2
# 4  19   2               2           22                1
#
#    EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0  1               4                        0       65
# 1  5               2                        1       65
# 2  3               3                        1       90
# 3  1               4                        0       97
# 4  2               4                        1       50
#
#    JobInvolvement  JobLevel  JobRole  JobSatisfaction  MaritalStatus  \
# 0  2               1         8        4                2
# 1  3               1         6        2                2
# 2  1               2         4        3                1
# 3  3               2         4        2                0
# 4  3               1         8        3                2
#
#    MonthlyIncome  MonthlyRate  NumCompaniesWorked  OverTime  \
# 0  3294           13137        1                   1
# 1  2718           17674        2                   0
# 2  4345           4381         0                   0
# 3  5131           9192         7                   0
# 4  1675           26820        1                   1
#
#    PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0  18                 3                  1
# 1  14                 3                  2
# 2  12                 3                  4
# 3  13                 3                  2
# 4  19                 3                  4
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0  0                 3                  3
# 1  0                 12                 3
# 2  1                 6                  2
# 3  3                 18                 3
# 4  0                 0                  2
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0  2                3               2
# 1  3                7               7
# 2  3                5               4
# 3  3                4               2
# 4  2                0               0
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0  1                        2
# 1  0                        7
# 2  1                        4
# 3  0                        2
# 4  0                        0

# %%
print("Test Dataset - Features: ")
# Out:
# Test Dataset - Features:

# %%
X_test.head()
# Out:
#       Age  BusinessTravel  Department  DistanceFromHome  Education  \
# 1274  31   2               2           29                4
# 539   50   2               2           8                 4
# 1395  31   1               2           26                4
# 1214  44   2               1           2                 3
# 494   34   2               2           14                3
#
#       EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 1274  2               1                        0       91
# 539   2               4                        1       54
# 1395  2               1                        1       63
# 1214  1               3                        0       96
# 494   5               3                        0       31
#
#       JobInvolvement  JobLevel  JobRole  JobSatisfaction  MaritalStatus  \
# 1274  2               2         7        4                1
# 539   3               1         8        2                1
# 1395  3               2         7        4                1
# 1214  4               3         0        4                1
# 494   3               1         8        3                0
#
#       MonthlyIncome  MonthlyRate  NumCompaniesWorked  OverTime  \
# 1274  5468           13402        1                   0
# 539   3875           9983         7                   0
# 1395  5617           21075        1                   1
# 1214  7879           14810        1                   1
# 494   2579           2912         1                   1
#
#       PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 1274  14                 3                  1
# 539   15                 3                  4
# 1395  11                 3                  3
# 1214  19                 3                  2
# 494   18                 3                  4
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 1274  2                 13                 3
# 539   1                 4                  2
# 1395  0                 10                 4
# 1214  1                 9                  2
# 494   2                 8                  3
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 1274  3                12              7
# 539   3                2               2
# 1395  3                10              7
# 1214  3                8               7
# 494   3                8               2
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 1274  5                        7
# 539   2                        2
# 1395  0                        8
# 1214  6                        7
# 494   0                        6

# %%
print("Train Dataset - Target: ")
# Out:
# Train Dataset - Target:

# %%
y_train.head()
# Out:
#    Attrition
# 0  0
# 1  0
# 2  0
# 3  0
# 4  1

# %%
print("Test Dataset - Target: ")
# Out:
# Test Dataset - Target:

# %%
y_test.head()
# Out:
#       Attrition
# 1274  0
# 539   0
# 1395  1
# 1214  0
# 494   0

# %% [markdown]
# #### Feature Scaling

# %%
# Scaling

scaler = StandardScaler()
# scaler = MinMaxScaler()

X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

X_train_sc_df = pd.DataFrame(scaler.fit_transform(X_train), columns=featlst)
X_test_sc_df = pd.DataFrame(scaler.transform(X_test), columns=featlst)

# %%
print("Train Dataset Scaled - Features:")
# Out:
# Train Dataset Scaled - Features:

# %%
X_train_sc_df.head()
# Out:
#         Age  BusinessTravel  Department  DistanceFromHome  Education  \
# 0  1.224023  0.611258        1.304641   -0.966873          1.093111
# 1 -0.356919 -2.579767       -0.497948   -0.607128          1.093111
# 2 -0.462315 -2.579767       -0.497948   -1.086788          1.093111
# 3  0.064666 -0.984255       -0.497948   -0.727043         -0.900937
# 4 -1.727069  0.611258        1.304641    1.431430         -1.897960
#
#    EducationField  EnvironmentSatisfaction    Gender  HourlyRate  \
# 0 -0.937509        1.233944                -1.232571  0.017836
# 1  1.947981       -0.538133                 0.811312  0.017836
# 2  0.505236        0.347905                 0.811312  1.260670
# 3 -0.937509        1.233944                -1.232571  1.608663
# 4 -0.216136        1.233944                 0.811312 -0.727864
#
#    JobInvolvement  JobLevel   JobRole  JobSatisfaction  MaritalStatus  \
# 0 -0.889970       -0.805067  1.359414  1.244561         1.090826
# 1  0.470626       -0.805067  0.564954 -0.558826         1.090826
# 2 -2.250567        0.135000 -0.229507  0.342867        -0.266071
# 3  0.470626        0.135000 -0.229507 -0.558826        -1.622967
# 4  0.470626       -0.805067  1.359414  0.342867         1.090826
#
#    MonthlyIncome  MonthlyRate  NumCompaniesWorked  OverTime  \
# 0 -0.545257      -0.171399    -0.714249            1.214338
# 1 -0.676069       0.461863    -0.323981           -0.823494
# 2 -0.306570      -1.393537    -1.104516           -0.823494
# 3 -0.128066      -0.722031     1.627355           -0.823494
# 4 -0.912939       1.738437    -0.714249            1.214338
#
#    PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0  0.776760          -0.420556          -1.574271
# 1 -0.315551          -0.420556          -0.645571
# 2 -0.861706          -0.420556           1.211830
# 3 -0.588628          -0.420556          -0.645571
# 4  1.049838          -0.420556           1.211830
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0 -0.799636         -0.898759           0.259235
# 1 -0.799636          0.258682           0.259235
# 2  0.365088         -0.512946          -0.537476
# 3  2.694535          1.030309           0.259235
# 4 -0.799636         -1.284573          -0.537476
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0 -0.895780        -0.511212       -0.456695
# 1  0.392865         0.142441        0.992340
# 2  0.392865        -0.184386        0.122919
# 3  0.392865        -0.347799       -0.456695
# 4 -0.895780        -1.001452       -1.036308
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0 -0.321848                -0.448607
# 1 -0.638262                 1.026574
# 2 -0.321848                 0.141465
# 3 -0.638262                -0.448607
# 4 -0.638262                -1.038680

# %%
print("Test Dataset Scaled - Features:")
# Out:
# Test Dataset Scaled - Features:

# %%
X_test_sc_df.head()
# Out:
#         Age  BusinessTravel  Department  DistanceFromHome  Education  \
# 0 -0.462315  0.611258        1.304641    2.270835          1.093111
# 1  1.540212  0.611258        1.304641   -0.247382          1.093111
# 2 -0.462315 -0.984255        1.304641    1.911090          1.093111
# 3  0.907835  0.611258       -0.497948   -0.966873          0.096087
# 4 -0.146127  0.611258        1.304641    0.472109          0.096087
#
#    EducationField  EnvironmentSatisfaction    Gender  HourlyRate  \
# 0 -0.216136       -1.424171                -1.232571  1.310383
# 1 -0.216136        1.233944                 0.811312 -0.529011
# 2 -0.216136       -1.424171                 0.811312 -0.081591
# 3 -0.937509        0.347905                -1.232571  1.558950
# 4  1.947981        0.347905                -1.232571 -1.672418
#
#    JobInvolvement  JobLevel   JobRole  JobSatisfaction  MaritalStatus  \
# 0 -0.889970        0.135000  0.962184  1.244561        -0.266071
# 1  0.470626       -0.805067  1.359414 -0.558826        -0.266071
# 2  0.470626        0.135000  0.962184  1.244561        -0.266071
# 3  1.831223        1.075067 -1.818427  1.244561        -0.266071
# 4  0.470626       -0.805067  1.359414  0.342867        -1.622967
#
#    MonthlyIncome  MonthlyRate  NumCompaniesWorked  OverTime  \
# 0 -0.051532      -0.134411    -0.714249           -0.823494
# 1 -0.413309      -0.611625     1.627355           -0.823494
# 2 -0.017693       0.936566    -0.714249            1.214338
# 3  0.496017       0.062114    -0.714249            1.214338
# 4 -0.707636      -1.598576    -0.714249            1.214338
#
#    PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0 -0.315551          -0.420556          -1.574271
# 1 -0.042473          -0.420556           1.211830
# 2 -1.134783          -0.420556           0.283129
# 3  1.049838          -0.420556          -0.645571
# 4  0.776760          -0.420556           1.211830
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0  1.529811          0.387286           0.259235
# 1  0.365088         -0.770155          -0.537476
# 2 -0.799636          0.001473           1.055947
# 3  0.365088         -0.127132          -0.537476
# 4  1.529811         -0.255737           0.259235
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0  0.392865         0.959507        0.992340
# 1  0.392865        -0.674625       -0.456695
# 2  0.392865         0.632680        0.992340
# 3  0.392865         0.305854        0.992340
# 4  0.392865         0.305854       -0.456695
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0  0.943806                 1.026574
# 1 -0.005435                -0.448607
# 2 -0.638262                 1.321610
# 3  1.260220                 1.026574
# 4 -0.638262                 0.731538

# %% [markdown]
# ### Machine Learning Models

# %% [markdown]
# #### Tuning Logistic Regression

# %%
# Hyperparameter Tuning for Logistic Regression Model

Log_Reg = LogisticRegression()

solvers = ['newton-cg', 'lbfgs', 'liblinear']
penalty = ['l2']
c_values = [1000, 100, 10, 1]

grid = {'solver':solvers,
       'penalty':penalty,
       'C':c_values,
        'class_weight':[{0:1, 1:w} for w in [1, 1.05, 1.2, 1.5, 2]]}

cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=RND_STATE)
grid_search = GridSearchCV(estimator=Log_Reg, param_grid=grid, n_jobs=-1, cv=cv, scoring=scoremet[0], error_score=0)
grid_result = grid_search.fit(X_train_sc, y_train)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))

means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

LR_Best = grid_search.best_params_
# Out:
# Best: 0.788933 using {'C': 1, 'class_weight': {0: 1, 1: 1.5}, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.787905 (0.012188) with: {'C': 1000, 'class_weight': {0: 1, 1: 1}, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.787905 (0.012188) with: {'C': 1000, 'class_weight': {0: 1, 1: 1}, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.787905 (0.012188) with: {'C': 1000, 'class_weight': {0: 1, 1: 1}, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.786445 (0.011278) with: {'C': 1000, 'class_weight': {0: 1, 1: 1.05}, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.786445 (0.011278) with: {'C': 1000, 'class_weight': {0: 1, 1: 1.05}, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.786445 (0.011278) with: {'C': 1000, 'class_weight': {0: 1, 1: 1.05}, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.786493 (0.010308) with: {'C': 1000, 'class_weight': {0: 1, 1: 1.2}, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.786493 (0.010308) with: {'C': 1000, 'class_weight': {0: 1, 1: 1.2}, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.786493 (0.010308) with: {'C': 1000, 'class_weight': {0: 1, 1: 1.2}, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.788578 (0.008195) with: {'C': 1000, 'class_weight': {0: 1, 1: 1.5}, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.788578 (0.008195) with: {'C': 1000, 'class_weight': {0: 1, 1: 1.5}, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.788578 (0.008195) with: {'C': 1000, 'class_weight': {0: 1, 1: 1.5}, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.781409 (0.009828) with: {'C': 1000, 'class_weight': {0: 1, 1: 2}, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.781297 (0.009771) with: {'C': 1000, 'class_weight': {0: 1, 1: 2}, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.781297 (0.009771) with: {'C': 1000, 'class_weight': {0: 1, 1: 2}, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.787905 (0.012188) with: {'C': 100, 'class_weight': {0: 1, 1: 1}, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.787905 (0.012188) with: {'C': 100, 'class_weight': {0: 1, 1: 1}, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.787905 (0.012188) with: {'C': 100, 'class_weight': {0: 1, 1: 1}, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.786445 (0.011278) with: {'C': 100, 'class_weight': {0: 1, 1: 1.05}, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.786445 (0.011278) with: {'C': 100, 'class_weight': {0: 1, 1: 1.05}, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.786445 (0.011278) with: {'C': 100, 'class_weight': {0: 1, 1: 1.05}, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.786493 (0.010308) with: {'C': 100, 'class_weight': {0: 1, 1: 1.2}, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.786493 (0.010308) with: {'C': 100, 'class_weight': {0: 1, 1: 1.2}, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.786493 (0.010308) with: {'C': 100, 'class_weight': {0: 1, 1: 1.2}, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.788578 (0.008195) with: {'C': 100, 'class_weight': {0: 1, 1: 1.5}, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.788578 (0.008195) with: {'C': 100, 'class_weight': {0: 1, 1: 1.5}, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.788578 (0.008195) with: {'C': 100, 'class_weight': {0: 1, 1: 1.5}, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.781409 (0.009828) with: {'C': 100, 'class_weight': {0: 1, 1: 2}, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.781297 (0.009771) with: {'C': 100, 'class_weight': {0: 1, 1: 2}, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.781409 (0.009828) with: {'C': 100, 'class_weight': {0: 1, 1: 2}, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.787905 (0.012188) with: {'C': 10, 'class_weight': {0: 1, 1: 1}, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.787905 (0.012188) with: {'C': 10, 'class_weight': {0: 1, 1: 1}, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.787905 (0.012188) with: {'C': 10, 'class_weight': {0: 1, 1: 1}, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.786959 (0.010782) with: {'C': 10, 'class_weight': {0: 1, 1: 1.05}, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.786959 (0.010782) with: {'C': 10, 'class_weight': {0: 1, 1: 1.05}, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.786959 (0.010782) with: {'C': 10, 'class_weight': {0: 1, 1: 1.05}, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.786610 (0.010236) with: {'C': 10, 'class_weight': {0: 1, 1: 1.2}, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.786610 (0.010236) with: {'C': 10, 'class_weight': {0: 1, 1: 1.2}, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.786610 (0.010236) with: {'C': 10, 'class_weight': {0: 1, 1: 1.2}, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.788578 (0.008195) with: {'C': 10, 'class_weight': {0: 1, 1: 1.5}, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.788578 (0.008195) with: {'C': 10, 'class_weight': {0: 1, 1: 1.5}, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.788578 (0.008195) with: {'C': 10, 'class_weight': {0: 1, 1: 1.5}, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.781305 (0.009979) with: {'C': 10, 'class_weight': {0: 1, 1: 2}, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.781305 (0.009979) with: {'C': 10, 'class_weight': {0: 1, 1: 2}, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.781515 (0.009844) with: {'C': 10, 'class_weight': {0: 1, 1: 2}, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.788344 (0.012263) with: {'C': 1, 'class_weight': {0: 1, 1: 1}, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.788344 (0.012263) with: {'C': 1, 'class_weight': {0: 1, 1: 1}, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.788344 (0.012263) with: {'C': 1, 'class_weight': {0: 1, 1: 1}, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.786896 (0.010420) with: {'C': 1, 'class_weight': {0: 1, 1: 1.05}, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.786896 (0.010420) with: {'C': 1, 'class_weight': {0: 1, 1: 1.05}, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.786896 (0.010420) with: {'C': 1, 'class_weight': {0: 1, 1: 1.05}, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.786430 (0.010131) with: {'C': 1, 'class_weight': {0: 1, 1: 1.2}, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.786430 (0.010131) with: {'C': 1, 'class_weight': {0: 1, 1: 1.2}, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.786546 (0.009941) with: {'C': 1, 'class_weight': {0: 1, 1: 1.2}, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.788821 (0.008205) with: {'C': 1, 'class_weight': {0: 1, 1: 1.5}, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.788821 (0.008205) with: {'C': 1, 'class_weight': {0: 1, 1: 1.5}, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.788933 (0.008110) with: {'C': 1, 'class_weight': {0: 1, 1: 1.5}, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.781419 (0.010159) with: {'C': 1, 'class_weight': {0: 1, 1: 2}, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.781419 (0.010159) with: {'C': 1, 'class_weight': {0: 1, 1: 2}, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.781084 (0.010221) with: {'C': 1, 'class_weight': {0: 1, 1: 2}, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
print("------ Logistic Regression Best Parameters ------")
# Out:
# ------ Logistic Regression Best Parameters ------

# %%
LR_Best
# Out:
# {'C': 1,
#  'class_weight': {0: 1, 1: 1.5},
#  'penalty': 'l2',
#  'solver': 'liblinear'}

# %% [markdown]
# #### Logistic Regression

# %%
# Model: Logistic Regression (LR)

Log_Reg = LogisticRegression(**LR_Best, random_state=RND_STATE).fit(X_train_sc, y_train)

# Prediction

y_pred = Log_Reg.predict(X_test_sc)

Train_Acc_LR = round(Log_Reg.score(X_train_sc, y_train),2)
Test_Acc_LR = round(Log_Reg.score(X_test_sc, y_test),2)

CM = confusion_matrix(y_test, y_pred)

TP_LR = CM[1, 1]
TN_LR = CM[0, 0]
FP_LR = CM[0, 1]
FN_LR = CM[1, 0]

Precision_LR = round(TP_LR/(TP_LR + FP_LR), 2)
Recall_LR = round(TP_LR/(TP_LR+FN_LR), 2)
f1_LR = round((2*Precision_LR*Recall_LR)/(Precision_LR+Recall_LR), 2)
Specificity_LR = round(TN_LR/(TN_LR+FP_LR), 2)
AUC_LR = round(roc_auc_score(y_test, y_pred), 2)

fpr_LR, tpr_LR, threshold_LR = roc_curve(y_test, y_pred, pos_label=1)

# %%
LR_Rep = classification_report(y_test, y_pred, output_dict=True)
LR_Rep_df = pd.DataFrame(LR_Rep).transpose()

# %%
print("-------- Logistic Regression Summary -------- ")
# Out:
# -------- Logistic Regression Summary --------

# %%
LR_Rep_df.head().round(decimals=2)
# Out:
#               precision  recall  f1-score  support
# 0             0.94       0.71    0.81      185.00
# 1             0.35       0.78    0.48      36.00
# accuracy      0.72       0.72    0.72      0.72
# macro avg     0.64       0.75    0.65      221.00
# weighted avg  0.85       0.72    0.76      221.00

# %% [markdown]
# #### Tuning Random Forest

# %%
# Hyperparameter Tunining for Random Forest Classifier (RFC)

RFC = RandomForestClassifier()

n_estimators = [100, 200, 300] # Number of Trees in the Forest
max_features = ['auto', 'sqrt']
max_depth = [3, 5] # max number of levels in each decision tree
min_samples_split = [2, 5]
criterion = ['entropy', 'gini']
weights = [1]

grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'criterion': criterion,
               'class_weight':  [{0:1, 1:weights} for weights in weights]
       }

cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=RND_STATE)
grid_search = GridSearchCV(estimator=RFC, param_grid=grid, n_jobs=-1, cv=cv, scoring=scoremet[0], error_score=0)
grid_result = grid_search.fit(X_train_sc, y_train)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))

means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

RFC_Best = grid_search.best_params_
# Out:
# Best: 0.851326 using {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 300}
# 0.756930 (0.032674) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 100}
# 0.758032 (0.035942) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 200}
# 0.755088 (0.029350) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 300}
# 0.756774 (0.028396) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 100}
# 0.756901 (0.031236) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 200}
# 0.754532 (0.030358) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 300}
# 0.757949 (0.035560) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100}
# 0.754875 (0.032765) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 200}
# 0.756540 (0.027859) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 300}
# 0.752297 (0.033118) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 100}
# 0.755763 (0.028497) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 200}
# 0.756081 (0.028199) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 300}
# 0.841512 (0.028034) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 100}
# 0.846083 (0.020131) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 200}
# 0.841928 (0.018919) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 300}
# 0.841546 (0.021794) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 100}
# 0.842223 (0.026054) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 200}
# 0.846655 (0.024677) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 300}
# 0.840731 (0.021139) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100}
# 0.840248 (0.024164) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 200}
# 0.842138 (0.024877) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 300}
# 0.841942 (0.028529) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 100}
# 0.845101 (0.022775) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 200}
# 0.841347 (0.022807) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 300}
# 0.751727 (0.032651) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 100}
# 0.758671 (0.032253) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 200}
# 0.757547 (0.027522) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 300}
# 0.759998 (0.032569) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 100}
# 0.756589 (0.027156) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 200}
# 0.758258 (0.030538) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 300}
# 0.755207 (0.031279) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100}
# 0.755238 (0.034627) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 200}
# 0.754143 (0.027473) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 300}
# 0.756080 (0.027471) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 100}
# 0.756873 (0.027461) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 200}
# 0.752793 (0.030674) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 300}
# 0.848545 (0.021374) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 100}
# 0.850676 (0.019737) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 200}
# 0.846783 (0.022910) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 300}
# 0.845623 (0.022552) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 100}
# 0.847157 (0.022657) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 200}
# 0.851326 (0.022348) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 300}
# 0.845833 (0.019283) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100}
# 0.846932 (0.019796) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 200}
# 0.849188 (0.019685) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 300}
# 0.845165 (0.021269) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 100}
# 0.847324 (0.019120) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 200}
# 0.845642 (0.026771) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 300}

# %%
print("------ Random Forest Best Parameters ------")
# Out:
# ------ Random Forest Best Parameters ------

# %%
RFC_Best
# Out:
# {'class_weight': {0: 1, 1: 1},
#  'criterion': 'gini',
#  'max_depth': 5,
#  'max_features': 'auto',
#  'min_samples_split': 5,
#  'n_estimators': 300}

# %% [markdown]
# #### Random Forest

# %%
# Model: Random Forest (RFC) 

RFC = RandomForestClassifier(**RFC_Best, random_state=RND_STATE)
RFC.fit(X_train_sc, y_train)

# Prediction

y_pred = RFC.predict(X_test_sc)

Train_Acc_RFC = round(RFC.score(X_train_sc, y_train),2)
Test_Acc_RFC = round(RFC.score(X_test_sc, y_test),2)

CM = confusion_matrix(y_test, y_pred)

TP_RFC = CM[1, 1]
TN_RFC = CM[0, 0]
FP_RFC = CM[0, 1]
FN_RFC = CM[1, 0]

Precision_RFC = round(TP_RFC/(TP_RFC + FP_RFC), 2)
Recall_RFC = round(TP_RFC/(TP_RFC+FN_RFC), 2)
f1_RFC = round((2*Precision_RFC*Recall_RFC)/(Precision_RFC+Recall_RFC), 2)
Specificity_RFC = round(TN_RFC/(TN_RFC+FP_RFC), 2)
AUC_RFC = round(roc_auc_score(y_test, y_pred), 2)

fpr_RFC, tpr_RFC, threshold_RFC = roc_curve(y_test, y_pred, pos_label=1)

# %%
RFC_Rep = classification_report(y_test, y_pred, output_dict=True)
RFC_Rep_df = pd.DataFrame(RFC_Rep).transpose()

# %%
print("-------- Random Forest Summary -------- ")
# Out:
# -------- Random Forest Summary --------

# %%
RFC_Rep_df.head().round(decimals=2)
# Out:
#               precision  recall  f1-score  support
# 0             0.90       0.90    0.90      185.00
# 1             0.49       0.50    0.49      36.00
# accuracy      0.83       0.83    0.83      0.83
# macro avg     0.69       0.70    0.70      221.00
# weighted avg  0.83       0.83    0.83      221.00

# %% [markdown]
# #### Tuning Extra Trees

# %%
# Hyperparameter Tunining for Extra Trees Classifier (ETC)

ETC = ExtraTreesClassifier()

n_estimators = [100, 200, 300] # Number of Trees in the Forest
max_features = ['auto', 'sqrt']
max_depth = [3, 5] # max number of levels in each decision tree
min_samples_split = [2, 5]
criterion = ['entropy', 'gini']
weights = [1]

grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'criterion': criterion,
               'class_weight':  [{0:1, 1:weights} for weights in weights]
       }

cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=RND_STATE)
grid_search = GridSearchCV(estimator=ETC, param_grid=grid, n_jobs=-1, cv=cv, scoring=scoremet[0], error_score=0)
grid_result = grid_search.fit(X_train_sc, y_train)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))

means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

ETC_Best = grid_search.best_params_
# Out:
# Best: 0.825356 using {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 100}
# 0.769336 (0.025879) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 100}
# 0.770631 (0.026504) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 200}
# 0.773977 (0.023211) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 300}
# 0.771578 (0.029985) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 100}
# 0.774753 (0.024551) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 200}
# 0.773129 (0.025417) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 300}
# 0.767890 (0.033497) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100}
# 0.770464 (0.030318) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 200}
# 0.774056 (0.022424) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 300}
# 0.764953 (0.030122) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 100}
# 0.774160 (0.022755) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 200}
# 0.775196 (0.029929) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 300}
# 0.817913 (0.024177) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 100}
# 0.821363 (0.017137) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 200}
# 0.822177 (0.019970) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 300}
# 0.825356 (0.017726) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 100}
# 0.817003 (0.021301) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 200}
# 0.820654 (0.023267) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 300}
# 0.819675 (0.023544) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100}
# 0.815505 (0.023870) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 200}
# 0.820446 (0.021421) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 300}
# 0.814095 (0.025042) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 100}
# 0.816539 (0.021690) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 200}
# 0.820275 (0.022408) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 300}
# 0.773986 (0.030114) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 100}
# 0.768637 (0.022815) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 200}
# 0.779203 (0.021924) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 300}
# 0.760878 (0.032919) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 100}
# 0.773290 (0.027214) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 200}
# 0.775857 (0.023897) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 300}
# 0.763090 (0.023470) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100}
# 0.775772 (0.026381) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 200}
# 0.773950 (0.026642) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 300}
# 0.769334 (0.026542) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 100}
# 0.769574 (0.025290) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 200}
# 0.770452 (0.023461) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 300}
# 0.818545 (0.024677) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 100}
# 0.820291 (0.023127) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 200}
# 0.819519 (0.026144) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 300}
# 0.819748 (0.022894) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 100}
# 0.821857 (0.020474) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 200}
# 0.822335 (0.023794) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 300}
# 0.825310 (0.024619) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100}
# 0.820453 (0.023802) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 200}
# 0.820054 (0.019755) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 300}
# 0.817911 (0.021936) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 100}
# 0.819492 (0.023567) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 200}
# 0.820352 (0.022258) with: {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 300}

# %%
print("------ Extra Trees Best Parameters ------")
# Out:
# ------ Extra Trees Best Parameters ------

# %%
ETC_Best
# Out:
# {'class_weight': {0: 1, 1: 1},
#  'criterion': 'entropy',
#  'max_depth': 5,
#  'max_features': 'auto',
#  'min_samples_split': 5,
#  'n_estimators': 100}

# %% [markdown]
# #### Extra Trees

# %%
# Model: Extra Trees (ETC) 

ETC = RandomForestClassifier(**ETC_Best, random_state=RND_STATE)
ETC.fit(X_train_sc, y_train)

# Prediction

y_pred = ETC.predict(X_test_sc)

Train_Acc_ETC = round(ETC.score(X_train_sc, y_train),2)
Test_Acc_ETC = round(ETC.score(X_test_sc, y_test),2)

CM = confusion_matrix(y_test, y_pred)

TP_ETC = CM[1, 1]
TN_ETC = CM[0, 0]
FP_ETC = CM[0, 1]
FN_ETC = CM[1, 0]

Precision_ETC = round(TP_ETC/(TP_ETC + FP_ETC), 2)
Recall_ETC = round(TP_ETC/(TP_ETC+FN_ETC), 2)
f1_ETC = round((2*Precision_ETC*Recall_ETC)/(Precision_ETC+Recall_ETC), 2)
Specificity_ETC = round(TN_ETC/(TN_ETC+FP_ETC), 2)
AUC_ETC = round(roc_auc_score(y_test, y_pred), 2)

fpr_ETC, tpr_ETC, threshold_ETC = roc_curve(y_test, y_pred, pos_label=1)

# %%
ETC_Rep = classification_report(y_test, y_pred, output_dict=True)
ETC_Rep_df = pd.DataFrame(RFC_Rep).transpose()

# %%
print("-------- Extra Trees Summary -------- ")
# Out:
# -------- Extra Trees Summary --------

# %%
ETC_Rep_df.head().round(decimals=2)
# Out:
#               precision  recall  f1-score  support
# 0             0.90       0.90    0.90      185.00
# 1             0.49       0.50    0.49      36.00
# accuracy      0.83       0.83    0.83      0.83
# macro avg     0.69       0.70    0.70      221.00
# weighted avg  0.83       0.83    0.83      221.00

# %% [markdown]
# #### Tuning Kernel SVM

# %%
# Model: Hyper Parameter Tuning for Kernel Support Vector Machines

KSV = svm.SVC()

kernel = ['rbf']
c_values = [1000, 100, 10, 1]
gamma = [0.1, 0.01]
weights = [1]

grid = {'kernel':kernel,
       'C':c_values,
        'gamma':gamma,
        'class_weight':[{0:1, 1:weights} for weights in weights]
       }

cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=RND_STATE)
grid_search = GridSearchCV(estimator=KSV, param_grid=grid, n_jobs=-1, cv=cv, scoring=scoremet[0], error_score=0)
grid_result = grid_search.fit(X_train_sc, y_train)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))

means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

KSV_Best = grid_search.best_params_
# Out:
# Best: 0.985576 using {'C': 1000, 'class_weight': {0: 1, 1: 1}, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.985576 (0.004963) with: {'C': 1000, 'class_weight': {0: 1, 1: 1}, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.940302 (0.012087) with: {'C': 1000, 'class_weight': {0: 1, 1: 1}, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.985576 (0.004963) with: {'C': 100, 'class_weight': {0: 1, 1: 1}, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.936689 (0.010988) with: {'C': 100, 'class_weight': {0: 1, 1: 1}, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.985576 (0.004963) with: {'C': 10, 'class_weight': {0: 1, 1: 1}, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.892081 (0.014356) with: {'C': 10, 'class_weight': {0: 1, 1: 1}, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.982419 (0.004962) with: {'C': 1, 'class_weight': {0: 1, 1: 1}, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.837534 (0.017247) with: {'C': 1, 'class_weight': {0: 1, 1: 1}, 'gamma': 0.01, 'kernel': 'rbf'}

# %%
print("------ Kernel SVM Best Parameters ------")
# Out:
# ------ Kernel SVM Best Parameters ------

# %%
KSV_Best
# Out:
# {'C': 1000, 'class_weight': {0: 1, 1: 1}, 'gamma': 0.1, 'kernel': 'rbf'}

# %% [markdown]
# #### Kernel SVM

# %%
# Model: Kernel Support Vector (KSV)

KSV = svm.SVC(**KSV_Best, random_state=RND_STATE)
KSV.fit(X_train_sc, y_train)

# Prediction

y_pred = KSV.predict(X_test_sc)

Train_Acc_KSV = round(KSV.score(X_train_sc, y_train),2)
Test_Acc_KSV = round(KSV.score(X_test_sc, y_test),2)

CM = confusion_matrix(y_test, y_pred)

TP_KSV = CM[1, 1]
TN_KSV = CM[0, 0]
FP_KSV = CM[0, 1]
FN_KSV = CM[1, 0]

Precision_KSV = round(TP_KSV/(TP_KSV + FP_KSV), 2)
Recall_KSV = round(TP_KSV/(TP_KSV+FN_KSV), 2)
f1_KSV = round((2*Precision_KSV*Recall_KSV)/(Precision_KSV+Recall_KSV), 2)
Specificity_KSV = round(TN_KSV/(TN_KSV+FP_KSV), 2)
AUC_KSV = round(roc_auc_score(y_test, y_pred), 2)

fpr_KSV, tpr_KSV, threshold_KSV = roc_curve(y_test, y_pred, pos_label=1)

# %%
KSV_Rep = classification_report(y_test, y_pred, output_dict=True)
KSV_Rep_df = pd.DataFrame(KSV_Rep).transpose()

# %%
print("-------- Kernel Support Vector Summary -------- ")
# Out:
# -------- Kernel Support Vector Summary --------

# %%
KSV_Rep_df.head().round(decimals=2)
# Out:
#               precision  recall  f1-score  support
# 0             0.85       0.99    0.92      185.00
# 1             0.80       0.11    0.20      36.00
# accuracy      0.85       0.85    0.85      0.85
# macro avg     0.83       0.55    0.56      221.00
# weighted avg  0.84       0.85    0.80      221.00

# %% [markdown]
# #### Tuning CatBoost

# %%
# Model: Hyperparameter Tuning for CatBoost Classification (CBC)

train_dataset = cb.Pool(X_train_sc, y_train)
test_dataset = cb.Pool(X_test_sc, y_test)

learning_rate = [0.01, 0.1]
depth= [4, 6, 10]
l2_leaf_reg =  [1, 3, 5,]
iterations = [100, 200, 300]
weights=[1.0, 2.0]

CBC = cb.CatBoostClassifier(loss_function='Logloss', eval_metric=scoremet_cbc[0])

grid = {'learning_rate':learning_rate,
        'depth': depth,
        'l2_leaf_reg':l2_leaf_reg,
        'iterations':iterations,
#         'class_weights': [{0:1, 1:weights} for weights in weights]
       }

CBC.grid_search(grid, train_dataset)
CBC.get_params ()
CBC_Best = CBC.get_params()
# Out:
# 0:	learn: 0.7260442	test: 0.6976744	best: 0.6976744 (0)	total: 147ms	remaining: 14.5s
# 1:	learn: 0.7021823	test: 0.6721311	best: 0.6976744 (0)	total: 148ms	remaining: 7.27s
# 2:	learn: 0.7160804	test: 0.6965699	best: 0.6976744 (0)	total: 150ms	remaining: 4.85s
# 3:	learn: 0.7487500	test: 0.7277487	best: 0.7277487 (3)	total: 151ms	remaining: 3.63s
# 4:	learn: 0.7447596	test: 0.7277487	best: 0.7277487 (3)	total: 153ms	remaining: 2.91s
# 5:	learn: 0.7400498	test: 0.7248677	best: 0.7277487 (3)	total: 155ms	remaining: 2.42s
# 6:	learn: 0.7448790	test: 0.7376623	best: 0.7376623 (6)	total: 156ms	remaining: 2.07s
# 7:	learn: 0.7520099	test: 0.7291667	best: 0.7376623 (6)	total: 158ms	remaining: 1.81s
# 8:	learn: 0.7490683	test: 0.7376623	best: 0.7376623 (6)	total: 159ms	remaining: 1.61s
# 9:	learn: 0.7495339	test: 0.7277487	best: 0.7376623 (6)	total: 161ms	remaining: 1.45s
# 10:	learn: 0.7456359	test: 0.7296588	best: 0.7376623 (6)	total: 162ms	remaining: 1.31s
# 11:	learn: 0.7570900	test: 0.7343750	best: 0.7376623 (6)	total: 164ms	remaining: 1.2s
# 17:	learn: 0.8414779	test: 0.7830424	best: 0.7830424 (17)	total: 27.9ms	remaining: 127ms
# 18:	learn: 0.8454707	test: 0.7841191	best: 0.7841191 (18)	total: 29.4ms	remaining: 125ms
# 19:	learn: 0.8457415	test: 0.7850000	best: 0.7850000 (19)	total: 31ms	remaining: 124ms
# 20:	learn: 0.8471148	test: 0.7858942	best: 0.7858942 (20)	total: 32.5ms	remaining: 122ms
# 21:	learn: 0.8522255	test: 0.7919799	best: 0.7919799 (21)	total: 34.1ms	remaining: 121ms
# 22:	learn: 0.8506841	test: 0.7970297	best: 0.7970297 (22)	total: 35.7ms	remaining: 119ms
# 23:	learn: 0.8554502	test: 0.8009950	best: 0.8009950 (23)	total: 37.2ms	remaining: 118ms
# 24:	learn: 0.8554502	test: 0.8029925	best: 0.8029925 (24)	total: 38.8ms	remaining: 116ms
# 25:	learn: 0.8545888	test: 0.8040201	best: 0.8040201 (25)	total: 40.3ms	remaining: 115ms
# 26:	learn: 0.8540798	test: 0.8020050	best: 0.8040201 (25)	total: 41.8ms	remaining: 113ms
# 27:	learn: 0.8571429	test: 0.8079800	best: 0.8079800 (27)	total: 43.4ms	remaining: 112ms
# 28:	learn: 0.8584962	test: 0.8079800	best: 0.8079800 (27)	total: 44.9ms	remaining: 110ms
# 29:	learn: 0.8654073	test: 0.8039702	best: 0.8079800 (27)	total: 46.5ms	remaining: 108ms
# 30:	learn: 0.8611931	test: 0.8059701	best: 0.8079800 (27)	total: 48ms	remaining: 107ms
# 31:	learn: 0.8642267	test: 0.8059701	best: 0.8079800 (27)	total: 49.5ms	remaining: 105ms
# 32:	learn: 0.8645465	test: 0.8100000	best: 0.8100000 (32)	total: 51.1ms	remaining: 104ms
# 33:	learn: 0.8765360	test: 0.8157248	best: 0.8157248 (33)	total: 52.6ms	remaining: 102ms
# 34:	learn: 0.8839650	test: 0.8146341	best: 0.8157248 (33)	total: 54.2ms	remaining: 101ms
# ...
# 190:	learn: 1.0000000	test: 0.9729730	best: 0.9729730 (167)	total: 2.55s	remaining: 1.46s
# 191:	learn: 1.0000000	test: 0.9729730	best: 0.9729730 (167)	total: 2.56s	remaining: 1.44s
# 192:	learn: 1.0000000	test: 0.9729730	best: 0.9729730 (167)	total: 2.58s	remaining: 1.43s
# 193:	learn: 1.0000000	test: 0.9729730	best: 0.9729730 (167)	total: 2.59s	remaining: 1.41s
# 194:	learn: 1.0000000	test: 0.9729730	best: 0.9729730 (167)	total: 2.6s	remaining: 1.4s
# 195:	learn: 1.0000000	test: 0.9729730	best: 0.9729730 (167)	total: 2.62s	remaining: 1.39s
# 196:	learn: 1.0000000	test: 0.9729730	best: 0.9729730 (167)	total: 2.63s	remaining: 1.37s
# 197:	learn: 1.0000000	test: 0.9729730	best: 0.9729730 (167)	total: 2.64s	remaining: 1.36s
# 198:	learn: 1.0000000	test: 0.9729730	best: 0.9729730 (167)	total: 2.66s	remaining: 1.35s
# 199:	learn: 1.0000000	test: 0.9729730	best: 0.9729730 (167)	total: 2.67s	remaining: 1.33s
# 200:	learn: 1.0000000	test: 0.9729730	best: 0.9729730 (167)	total: 2.69s	remaining: 1.32s
# 201:	learn: 1.0000000	test: 0.9729730	best: 0.9729730 (167)	total: 2.7s	remaining: 1.31s
# 202:	learn: 1.0000000	test: 0.9729730	best: 0.9729730 (167)	total: 2.71s	remaining: 1.29s
# 203:	learn: 1.0000000	test: 0.9705882	best: 0.9729730 (167)	total: 2.72s	remaining: 1.28s
# 204:	learn: 1.0000000	test: 0.9705882	best: 0.9729730 (167)	total: 2.74s	remaining: 1.27s
# 205:	learn: 1.0000000	test: 0.9682152	best: 0.9729730 (167)	total: 2.75s	remaining: 1.25s
# 206:	learn: 1.0000000	test: 0.9705882	best: 0.9729730 (167)	total: 2.76s	remaining: 1.24s
# 207:	learn: 1.0000000	test: 0.9705882	best: 0.9729730 (167)	total: 2.77s	remaining: 1.23s
# 208:	learn: 1.0000000	test: 0.9705882	best: 0.9729730 (167)	total: 2.79s	remaining: 1.21s
# 209:	learn: 1.0000000	test: 0.9705882	best: 0.9729730 (167)	total: 2.8s	remaining: 1.2s
# 210:	learn: 1.0000000	test: 0.9705882	best: 0.9729730 (167)	total: 2.81s	remaining: 1.19s
# 211:	learn: 1.0000000	test: 0.9705882	best: 0.9729730 (167)	total: 2.83s	remaining: 1.17s
# 212:	learn: 1.0000000	test: 0.9705882	best: 0.9729730 (167)	total: 2.84s	remaining: 1.16s
# 213:	learn: 1.0000000	test: 0.9705882	best: 0.9729730 (167)	total: 2.86s	remaining: 1.15s
# 214:	learn: 1.0000000	test: 0.9705882	best: 0.9729730 (167)	total: 2.87s	remaining: 1.13s
# 215:	learn: 1.0000000	test: 0.9705882	best: 0.9729730 (167)	total: 2.88s	remaining: 1.12s
# 216:	learn: 1.0000000	test: 0.9682152	best: 0.9729730 (167)	total: 2.9s	remaining: 1.11s
# 217:	learn: 1.0000000	test: 0.9682152	best: 0.9729730 (167)	total: 2.91s	remaining: 1.09s
# 218:	learn: 1.0000000	test: 0.9682152	best: 0.9729730 (167)	total: 2.92s	remaining: 1.08s
# 219:	learn: 1.0000000	test: 0.9682152	best: 0.9729730 (167)	total: 2.93s	remaining: 1.07s
# 220:	learn: 1.0000000	test: 0.9705882	best: 0.9729730 (167)	total:
# 81:	learn: 1.0000000	test: 0.9704551	best: 0.9736315 (67)
# 82:	learn: 1.0000000	test: 0.9704401	best: 0.9736315 (67)
# 83:	learn: 1.0000000	test: 0.9704401	best: 0.9736315 (67)
# 84:	learn: 1.0000000	test: 0.9689601	best: 0.9736315 (67)
# 85:	learn: 1.0000000	test: 0.9694232	best: 0.9736315 (67)
# 86:	learn: 1.0000000	test: 0.9703283	best: 0.9736315 (67)
# 87:	learn: 1.0000000	test: 0.9703283	best: 0.9736315 (67)
# 88:	learn: 1.0000000	test: 0.9698652	best: 0.9736315 (67)
# 89:	learn: 1.0000000	test: 0.9694095	best: 0.9736315 (67)
# 90:	learn: 1.0000000	test: 0.9703283	best: 0.9736315 (67)
# 91:	learn: 1.0000000	test: 0.9694158	best: 0.9736315 (67)
# 92:	learn: 1.0000000	test: 0.9694095	best: 0.9736315 (67)
# 93:	learn: 1.0000000	test: 0.9698726	best: 0.9736315 (67)	total: 7.5s	remaining: 479ms
# 94:	learn: 1.0000000	test: 0.9698726	best: 0.9736315 (67)
# 95:	learn: 1.0000000	test: 0.9703283	best: 0.9736315 (67)
# 96:	learn: 1.0000000	test: 0.9703283	best: 0.9736315 (67)
# 97:	learn: 1.0000000	test: 0.9703283	best: 0.9736315 (67)
# 98:	learn: 1.0000000	test: 0.9703283	best: 0.9736315 (67)
# 99:	learn: 1.0000000	test: 0.9698726	best: 0.9736315 (67)	total: 9.54s	remaining: 0us

# %%
print("------ CatBoost Classification Best Parameters ------")
# Out:
# ------ CatBoost Classification Best Parameters ------

# %%
CBC_Best
# Out:
# {'loss_function': 'Logloss',
#  'eval_metric': 'F1',
#  'depth': 10,
#  'l2_leaf_reg': 1,
#  'iterations': 100,
#  'learning_rate': 0.1}

# %% [markdown]
# #### CatBoost

# %%
# Model: CatBoost Classification (CBC)

CBC= cb.CatBoostClassifier(**CBC_Best, random_seed=RND_STATE)
CBC.fit(X_train_sc, y_train)

# Prediction

y_pred = CBC.predict(X_test_sc)

Train_Acc_CBC = round(CBC.score(X_train_sc, y_train),2)
Test_Acc_CBC = round(CBC.score(X_test_sc, y_test),2)

CM = confusion_matrix(y_test, y_pred)

TP_CBC = CM[1, 1]
TN_CBC = CM[0, 0]
FP_CBC = CM[0, 1]
FN_CBC = CM[1, 0]

Precision_CBC = round(TP_CBC/(TP_CBC + FP_CBC), 2)
Recall_CBC = round(TP_CBC/(TP_CBC+FN_CBC), 2)
f1_CBC = round((2*Precision_CBC*Recall_CBC)/(Precision_CBC+Recall_CBC), 2)
Specificity_CBC = round(TN_CBC/(TN_CBC+FP_CBC), 2)
AUC_CBC = round(roc_auc_score(y_test, y_pred), 2)

fpr_CBC, tpr_CBC, threshold_CBC = roc_curve(y_test, y_pred, pos_label=1)
# Out:
# 0:	learn: 0.8728111	total: 15.1ms	remaining: 1.49s
# 1:	learn: 0.9329556	total: 29.6ms	remaining: 1.45s
# 2:	learn: 0.9415677	total: 43.7ms	remaining: 1.41s
# 3:	learn: 0.9621466	total: 57.4ms	remaining: 1.38s
# 4:	learn: 0.9798851	total: 71.3ms	remaining: 1.35s
# 5:	learn: 0.9823220	total: 86.2ms	remaining: 1.35s
# 6:	learn: 0.9856734	total: 101ms	remaining: 1.34s
# 7:	learn: 0.9885167	total: 115ms	remaining: 1.32s
# 8:	learn: 0.9942748	total: 130ms	remaining: 1.31s
# 9:	learn: 0.9971374	total: 144ms	remaining: 1.29s
# 10:	learn: 0.9985694	total: 157ms	remaining: 1.27s
# 61:	learn: 1.0000000	total: 857ms	remaining: 525ms
# 62:	learn: 1.0000000	total: 869ms	remaining: 510ms
# 63:	learn: 1.0000000	total: 882ms	remaining: 496ms
# 64:	learn: 1.0000000	total: 895ms	remaining: 482ms
# 65:	learn: 1.0000000	total: 908ms	remaining: 468ms
# 66:	learn: 1.0000000	total: 921ms	remaining: 453ms
# 67:	learn: 1.0000000	total: 933ms	remaining: 439ms
# 68:	learn: 1.0000000	total: 946ms	remaining: 425ms
# 69:	learn: 1.0000000	total: 958ms	remaining: 411ms
# 70:	learn: 1.0000000	total: 971ms	remaining: 396ms
# 71:	learn: 1.0000000	total: 983ms	remaining: 382ms
# 72:	learn: 1.0000000	total: 996ms	remaining: 368ms
# 73:	learn: 1.0000000	total: 1.01s	remaining: 355ms
# 74:	learn: 1.0000000	total: 1.02s	remaining: 341ms
# 75:	learn: 1.0000000	total: 1.03s	remaining: 327ms
# 76:	learn: 1.0000000	total: 1.05s	remaining: 313ms
# 77:	learn: 1.0000000	total: 1.06s	remaining: 299ms
# 78:	learn: 1.0000000	total: 1.07s	remaining: 285ms
# 79:	learn: 1.0000000	total: 1.08s	remaining: 271ms
# 80:	learn: 1.0000000	total: 1.1s	remaining: 257ms
# 81:	learn: 1.0000000	total: 1.11s	remaining: 244ms
# 82:	learn: 1.0000000	total: 1.12s	remaining: 230ms
# 83:	learn: 1.0000000	total: 1.13s	remaining: 216ms
# 84:	learn: 1.0000000	total: 1.15s	remaining: 202ms
# 85:	learn: 1.0000000	total: 1.16s	remaining: 189ms
# 86:	learn: 1.0000000	total: 1.17s	remaining: 175ms
# 87:	learn: 1.0000000	total: 1.18s	remaining: 161ms
# 88:	learn: 1.0000000	total: 1.2s	remaining: 148ms
# 89:	learn: 1.0000000	total: 1.21s	remaining: 134ms
# 90:	learn: 1.0000000	total: 1.22s	remaining: 121ms
# 91:	learn: 1.0000000	total: 1.24s	remaining: 107ms
# 92:	learn: 1.0000000	total: 1.25s	remaining: 93.9ms
# 93:	learn: 1.0000000	total: 1.26s	remaining: 80.5ms
# 94:	learn: 1.0000000	total: 1.27s	remaining: 67ms
# 95:	learn: 1.0000000	total: 1.28s	remaining: 53.6ms
# 96:	learn: 1.0000000	total: 1.3s	remaining: 40.1ms
# 97:	learn: 1.0000000	total: 1.31s	remaining: 26.8ms
# 98:	learn: 1.0000000	total: 1.32s	remaining: 13.4ms
# 99:	learn: 1.0000000	total: 1.33s	remaining: 0us

# %%
CBC_Rep = classification_report(y_test, y_pred, output_dict=True)
CBC_Rep_df = pd.DataFrame(CBC_Rep).transpose()

# %%
print("-------- CatBoost Classification Summary -------- ")
# Out:
# -------- CatBoost Classification Summary --------

# %%
CBC_Rep_df.head().round(decimals=2)
# Out:
#               precision  recall  f1-score  support
# 0             0.86       1.00    0.93      185.00
# 1             1.00       0.19    0.33      36.00
# accuracy      0.87       0.87    0.87      0.87
# macro avg     0.93       0.60    0.63      221.00
# weighted avg  0.89       0.87    0.83      221.00

# %% [markdown]
# #### Multi-Layer Perceptron

# %%
# Multi Layer Perceptron Classifier - MLP

MLP = MLPClassifier(hidden_layer_sizes=(300, 300), max_iter=300, alpha=1e-4, activation='relu', solver='adam', random_state=RND_STATE)
MLP.fit(X_train_sc, y_train)

# Evaluate the Model

y_pred = MLP.predict(X_test_sc).astype(int)

Train_Acc_MLP = round(MLP.score(X_train_sc, y_train),2)
Test_Acc_MLP = round(MLP.score(X_test_sc, y_test),2)

CM = confusion_matrix(y_test, y_pred)

TP_MLP = CM[1, 1]
TN_MLP = CM[0, 0]
FP_MLP = CM[0, 1]
FN_MLP = CM[1, 0]

Precision_MLP = round(TP_MLP/(TP_MLP + FP_MLP), 2)
Recall_MLP = round(TP_MLP/(TP_MLP + FN_MLP), 2)
f1_MLP = round((2*Precision_MLP*Recall_MLP)/(Precision_MLP+Recall_MLP), 2)
Specificity_MLP = round(TN_MLP/(TN_MLP+FP_MLP), 2)
AUC_MLP = round(roc_auc_score(y_test, y_pred), 2)

fpr_MLP, tpr_MLP, threshold_MLP = roc_curve(y_test, y_pred, pos_label=1)

# %%
MLP_Rep = classification_report(y_test, y_pred, output_dict=True)
MLP_Rep_df = pd.DataFrame(MLP_Rep).transpose()

MLP_Best = {}

# %%
print("-------- Multi Layer Perceptron Classifier -------- ")
# Out:
# -------- Multi Layer Perceptron Classifier --------

# %%
MLP_Rep_df.head().round(decimals=2)
# Out:
#               precision  recall  f1-score  support
# 0             0.89       0.95    0.92      185.00
# 1             0.61       0.39    0.47      36.00
# accuracy      0.86       0.86    0.86      0.86
# macro avg     0.75       0.67    0.70      221.00
# weighted avg  0.84       0.86    0.85      221.00

# %% [markdown]
# #### Voting Classifier

# %%
# Voting Classifier

VOC = VotingClassifier(estimators=[('RFC', RFC), ('ETC', ETC)], voting='soft',
                       weights=[1,1], flatten_transform=True, n_jobs=-1)
VOC.fit(X_train_sc, y_train)

# Evaluate the Model

y_pred = VOC.predict(X_test_sc).astype(int)

Train_Acc_VOC = round(VOC.score(X_train_sc, y_train),2)
Test_Acc_VOC = round(VOC.score(X_test_sc, y_test),2)

CM = confusion_matrix(y_test, y_pred)

TP_VOC = CM[1, 1]
TN_VOC = CM[0, 0]
FP_VOC = CM[0, 1]
FN_VOC = CM[1, 0]

Precision_VOC = round(TP_VOC/(TP_VOC + FP_VOC), 2)
Recall_VOC = round(TP_VOC/(TP_VOC + FN_VOC), 2)
f1_VOC = round((2*Precision_VOC*Recall_VOC)/(Precision_VOC+Recall_VOC), 2)
Specificity_VOC = round(TN_VOC/(TN_VOC+FP_VOC), 2)
AUC_VOC = round(roc_auc_score(y_test, y_pred), 2)

fpr_VOC, tpr_VOC, threshold_VOC = roc_curve(y_test, y_pred, pos_label=1)

# %%
VOC_Rep = classification_report(y_test, y_pred, output_dict=True)
VOC_Rep_df = pd.DataFrame(VOC_Rep).transpose()

VOC_Best = {}

# %%
print("-------- Votiing Classifier -------- ")
# Out:
# -------- Votiing Classifier --------

# %%
VOC_Rep_df.head().round(decimals=2)
# Out:
#               precision  recall  f1-score  support
# 0             0.90       0.89    0.89      185.00
# 1             0.46       0.47    0.47      36.00
# accuracy      0.82       0.82    0.82      0.82
# macro avg     0.68       0.68    0.68      221.00
# weighted avg  0.83       0.82    0.82      221.00

# %% [markdown]
# #### Stacking Classifier

# %%
# Stacking Classifier

STC = StackingClassifier(estimators=[('RFC', RFC), ('ETC', ETC)], final_estimator=MLP, passthrough=False, n_jobs=-1)
STC.fit(X_train_sc, y_train)

# Evaluate the Model

y_pred = STC.predict(X_test_sc).astype(int)

Train_Acc_STC = round(STC.score(X_train_sc, y_train),2)
Test_Acc_STC = round(STC.score(X_test_sc, y_test),2)

CM = confusion_matrix(y_test, y_pred)

TP_STC = CM[1, 1]
TN_STC = CM[0, 0]
FP_STC = CM[0, 1]
FN_STC = CM[1, 0]

Precision_STC = round(TP_STC/(TP_STC + FP_STC), 2)
Recall_STC = round(TP_STC/(TP_STC + FN_STC), 2)
f1_STC = round((2*Precision_STC*Recall_STC)/(Precision_STC+Recall_STC), 2)
Specificity_STC = round(TN_STC/(TN_STC+FP_STC), 2)
AUC_STC = round(roc_auc_score(y_test, y_pred), 2)

fpr_STC, tpr_STC, threshold_STC = roc_curve(y_test, y_pred, pos_label=1)

# %%
STC_Rep = classification_report(y_test, y_pred, output_dict=True)
STC_Rep_df = pd.DataFrame(STC_Rep).transpose()

STC_Best = {}

# %%
print("-------- Stacking Classifier -------- ")
# Out:
# -------- Stacking Classifier --------

# %%
STC_Rep_df.head().round(decimals=2)
# Out:
#               precision  recall  f1-score  support
# 0             0.90       0.89    0.90      185.00
# 1             0.47       0.50    0.49      36.00
# accuracy      0.83       0.83    0.83      0.83
# macro avg     0.69       0.70    0.69      221.00
# weighted avg  0.83       0.83    0.83      221.00

# %% [markdown]
# ### Results & Output

# %% [markdown]
# #### Output to Excel

# %%
modlst = ['Logistic_Regression', 'Random_Forest', 'Extra_Trees', 'Kernel_SVM', 'CatBoost', 'MLP', 'VOC', 'STC']
nmodels = int(len(modlst))

score1 = ['Train_Acc_LR', 'Train_Acc_RFC', 'Train_Acc_ETC', 'Train_Acc_KSV', 'Train_Acc_CBC', 'Train_Acc_MLP', 'Train_Acc_VOC', 'Train_Acc_STC']
score2 = ['Test_Acc_LR', 'Test_Acc_RFC', 'Test_Acc_ETC', 'Test_Acc_KSV', 'Test_Acc_CBC', 'Test_Acc_MLP', 'Test_Acc_VOC', 'Test_Acc_STC']
score3 = ['TP_LR', 'TP_RFC', 'TP_ETC', 'TP_KSV',  'TP_CBC', 'TP_MLP', 'TP_VOC', 'TP_STC']
score4 = ['TN_LR', 'TN_RFC', 'TN_ETC', 'TN_KSV', 'TN_CBC', 'TN_MLP', 'TN_VOC', 'TN_STC']
score5 = ['FP_LR', 'FP_RFC', 'FP_ETC', 'FP_KSV', 'FP_CBC', 'FP_MLP', 'FP_VOC', 'FP_STC']
score6 = ['FN_LR', 'FN_RFC', 'FN_ETC', 'FN_KSV', 'FN_CBC', 'FN_MLP', 'FN_VOC', 'FN_STC']
score7 = ['Precision_LR', 'Precision_RFC', 'Precision_ETC', 'Precision_KSV', 'Precision_CBC', 'Precision_MLP', 'Precision_VOC', 'Precision_STC']
score8 = ['Recall_LR', 'Recall_RFC', 'Recall_ETC', 'Recall_KSV', 'Recall_CBC', 'Recall_MLP', 'Recall_VOC', 'Recall_STC']
score9 = ['f1_LR', 'f1_RFC', 'f1_ETC', 'f1_KSV', 'f1_CBC', 'f1_MLP', 'f1_VOC', 'f1_STC']
score10 = ['Specificity_LR', 'Specificity_RFC', 'Specificity_ETC', 'Specificity_KSV', 'Specificity_CBC', 'Specificity_MLP', 'Specificity_VOC', 'Specificity_STC']
score11 = ['AUC_LR', 'AUC_RFC', 'AUC_ETC', 'AUC_KSV', 'AUC_CBC', 'AUC_MLP', 'AUC_VOC', 'AUC_STC']
score12 = ['LR_Best',  'RFC_Best', 'ETC_Best', 'KSV_Best', 'CBC_Best', 'MLP_Best', 'VOC_Best', 'STC_Best']

trainacclst = []
testacclst = []
tplst = []
tnlst = []
fplst = []
fnlst = []
precisionlst = []
recalllst = []
f1scorelst = []
specificitylst = []
auclst = []
bestparlst = []

for i in range(0, len(modlst)):
    var1 = vars()[score1[i]]
    var2 = vars()[score2[i]]
    var3 = vars()[score3[i]]
    var4 = vars()[score4[i]]
    var5 = vars()[score5[i]]
    var6 = vars()[score6[i]]
    var7 = vars()[score7[i]]
    var8 = vars()[score8[i]]
    var9 = vars()[score9[i]]
    var10 = vars()[score10[i]]
    var11 = vars()[score11[i]]
    var12 = vars()[score12[i]]
    
    trainacclst.append(var1)
    testacclst.append(var2)
    tplst.append(var3)
    tnlst.append(var4)
    fplst.append(var5)
    fnlst.append(var6)
    precisionlst.append(var7)
    recalllst.append(var8)
    f1scorelst.append(var9)
    specificitylst.append(var10)
    auclst.append(var11)
    bestparlst.append(var12)

summary = pd.DataFrame(np.column_stack([modlst, trainacclst, testacclst, tplst, tnlst, fplst, fnlst,
                                        precisionlst, recalllst, f1scorelst, specificitylst, auclst, bestparlst]),
                       columns=['Model_Name', 'Train_Accuracy', 'Test_Accuracy', 'True_Pos', 'True_Neg',
                                'False_Pos', 'False_Neg', 'Precision', 'Recall', 'f1-Score',
                                'Specificity', 'AUC', 'Best_Params'])

# %% [markdown]
# #### Model Evaluation Summary

# %%
print("Evaluation Summary:")
# Out:
# Evaluation Summary:

# %%
summary.head(nmodels)
# Out:
#             Model_Name Train_Accuracy Test_Accuracy True_Pos True_Neg  \
# 0  Logistic_Regression  0.78           0.72          28       132
# 1  Random_Forest        0.89           0.83          18       166
# 2  Extra_Trees          0.88           0.84          19       167
# 3  Kernel_SVM           1.0            0.85          4        184
# 4  CatBoost             1.0            0.87          7        185
# 5  MLP                  1.0            0.86          14       176
# 6  VOC                  0.89           0.82          17       165
# 7  STC                  0.89           0.83          18       165
#
#   False_Pos False_Neg Precision Recall f1-Score Specificity   AUC  \
# 0  53        8         0.35      0.78   0.48     0.71        0.75
# 1  19        18        0.49      0.5    0.49     0.9         0.7
# 2  18        17        0.51      0.53   0.52     0.9         0.72
# 3  1         32        0.8       0.11   0.19     0.99        0.55
# 4  0         29        1.0       0.19   0.32     1.0         0.6
# 5  9         22        0.61      0.39   0.48     0.95        0.67
# 6  20        19        0.46      0.47   0.46     0.89        0.68
# 7  20        18        0.47      0.5    0.48     0.89        0.7
#
#                                                                                                                                    Best_Params
# 0  {'C': 1, 'class_weight': {0: 1, 1: 1.5}, 'penalty': 'l2', 'solver': 'liblinear'}
# 1  {'class_weight': {0: 1, 1: 1}, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 300}
# 2  {'class_weight': {0: 1, 1: 1}, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_split': 5, 'n_estimators': 100}
# 3  {'C': 1000, 'class_weight': {0: 1, 1: 1}, 'gamma': 0.1, 'kernel': 'rbf'}
# 4  {'loss_function': 'Logloss', 'eval_metric': 'F1', 'depth': 10, 'l2_leaf_reg': 1, 'iterations': 100, 'learning_rate': 0.1}
# 5  {}
# 6  {}
# 7  {}

# %%
Classification_Report_Summary = (pd.concat([LR_Rep_df, RFC_Rep_df, ETC_Rep_df, KSV_Rep_df, CBC_Rep_df, MLP_Rep_df, VOC_Rep_df, STC_Rep_df],
                keys=['LR_Rep_df', 'RFC_Rep_df', 'ETC_Rep_df', 'KSV_Rep_df', 'CBC_Rep_df', 'MLP_Rep_df', 'VOC_Rep_df', 'STC_Rep_df'])).round(decimals=2)

# %%
print("------ Classification Report Summary ------")
# Out:
# ------ Classification Report Summary ------

# %%
Classification_Report_Summary
# Out:
#                          precision  recall  f1-score  support
# LR_Rep_df  0             0.94       0.71    0.81      185.00
#            1             0.35       0.78    0.48      36.00
#            accuracy      0.72       0.72    0.72      0.72
#            macro avg     0.64       0.75    0.65      221.00
#            weighted avg  0.85       0.72    0.76      221.00
# RFC_Rep_df 0             0.90       0.90    0.90      185.00
#            1             0.49       0.50    0.49      36.00
#            accuracy      0.83       0.83    0.83      0.83
#            macro avg     0.69       0.70    0.70      221.00
#            weighted avg  0.83       0.83    0.83      221.00
# ETC_Rep_df 0             0.90       0.90    0.90      185.00
#            1             0.49       0.50    0.49      36.00
#            accuracy      0.83       0.83    0.83      0.83
#            macro avg     0.69       0.70    0.70      221.00
#            weighted avg  0.83       0.83    0.83      221.00
# KSV_Rep_df 0             0.85       0.99    0.92      185.00
#            1             0.80       0.11    0.20      36.00
#            accuracy      0.85       0.85    0.85      0.85
#            macro avg     0.83       0.55    0.56      221.00
#            weighted avg  0.84       0.85    0.80      221.00
# CBC_Rep_df 0             0.86       1.00    0.93      185.00
#            1             1.00       0.19    0.33      36.00
#            accuracy      0.87       0.87    0.87      0.87
#            macro avg     0.93       0.60    0.63      221.00
#            weighted avg  0.89       0.87    0.83      221.00
# MLP_Rep_df 0             0.89       0.95    0.92      185.00
#            1             0.61       0.39    0.47      36.00
#            accuracy      0.86       0.86    0.86      0.86
#            macro avg     0.75       0.67    0.70      221.00
#            weighted avg  0.84       0.86    0.85      221.00
# VOC_Rep_df 0             0.90       0.89    0.89      185.00
#            1             0.46       0.47    0.47      36.00
#            accuracy      0.82       0.82    0.82      0.82
#            macro avg     0.68       0.68    0.68      221.00
#            weighted avg  0.83       0.82    0.82      221.00
# STC_Rep_df 0             0.90       0.89    0.90      185.00
#            1             0.47       0.50    0.49      36.00
#            accuracy      0.83       0.83    0.83      0.83
#            macro avg     0.69       0.70    0.69      221.00
#            weighted avg  0.83       0.83    0.83      221.00

# %% [markdown]
# #### ROC Curve

# %%
prob = [0 for i in range(len(y_test))]
prob_fpr, prob_tpr, threshold = roc_curve(y_test, prob, pos_label=1)

plt.plot(fpr_LR, tpr_LR, linestyle='-', color='tab:blue', label='Logistic_Regression')
plt.plot(fpr_RFC, tpr_RFC, linestyle='-', color='tab:orange', label='Random_Forest')
plt.plot(fpr_ETC, tpr_ETC, linestyle='-', color='tab:green', label='Extra_Trees')
plt.plot(fpr_KSV, tpr_KSV, linestyle='-', color='tab:red', label='Kernel_SVM')
plt.plot(fpr_CBC, tpr_CBC, linestyle='-', color='tab:purple', label='CatBoost')
plt.plot(fpr_MLP, tpr_MLP, linestyle='-', color='tab:brown', label='Multilayer_Perceptron')
plt.plot(fpr_VOC, tpr_VOC, linestyle='-', color='tab:pink', label='Voting_Classifier')
plt.plot(fpr_STC, tpr_STC, linestyle='-', color='tab:grey', label='Stacking_Classfier')
plt.plot(prob_fpr, prob_tpr, linestyle='--', color='tab:olive', label="Coin_Flip")
plt.xlim([-0.05, 1.05])
plt.ylim([-.05, 1.05])
plt.title('ROC_Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #### Precision Recall Curve

# %%
from sklearn.metrics import plot_precision_recall_curve

plot_precision_recall_curve(Log_Reg, X_test_sc, y_test, ax = plt.gca(), linestyle='-', color='tab:blue', name = "Logistic_Regression")
plot_precision_recall_curve(RFC, X_test_sc, y_test, ax = plt.gca(), linestyle='-', color='tab:orange', name = "Random_Forest")
plot_precision_recall_curve(ETC, X_test_sc, y_test, ax = plt.gca(), linestyle='-', color='tab:green', name = "Extra_Trees")
plot_precision_recall_curve(KSV, X_test_sc, y_test, ax = plt.gca(), linestyle='-', color='tab:red', name = "Kernel_SVM")
plot_precision_recall_curve(CBC, X_test_sc, y_test, ax = plt.gca(), linestyle='-', color='tab:purple', name = "CatBoost")
plot_precision_recall_curve(MLP, X_test_sc, y_test, ax = plt.gca(), linestyle='-', color='tab:brown', name = "Multilayer_Perceptron")
plot_precision_recall_curve(STC, X_test_sc, y_test, ax = plt.gca(), linestyle='-', color='tab:grey', name = "Stacking_Classifier")
plt.legend(loc='best')
plt.title('Precision-Recall curve')
# Out:
# Text(0.5, 1.0, 'Precision-Recall curve')

# %% [markdown]
# #### SHAP Model Explainer

# %%
# Model Explainability Using SHAP - CatBoost Classifier

explainer = shap.TreeExplainer(CBC) # Only works for tree based models such as DTC, RFC, ETC, CatBoost 
shap_values = explainer.shap_values(X_train_sc)

# %%
print("------ Feature Importance Using SHAP ------")
# Out:
# ------ Feature Importance Using SHAP ------

# %%
shap.summary_plot(shap_values, X_train_sc, feature_names=featlst, plot_type='violin', max_display=len(featlst), title='CatBoost Model Explainer')

# %%
OUTFILE = r"Summary.xlsx"

writer = pd.ExcelWriter(f"{OUTPATH}{PREFIX}{OUTFILE}", engine='xlsxwriter', options={'strings_to_numbers': True})
summary.to_excel(writer, sheet_name='Metrics', index=False)
Classification_Report_Summary.to_excel(writer, sheet_name='CLF_Report', index=True)
writer.save()

# %% [markdown]
# #### Notebook to HTML

# %%
# !jupyter nbconvert --output-dir="C:\DSML_Case_Studies\01_Classification\00_Final_Reports" GS_MLM_CLF_V2.2.ipynb --to html

# %%
NB_Convert = u"jupyter nbconvert --to html_toc --output " # Trailing space is required.
NB_Name = u"GS_MLM_CLF_V2.2_IBM_Attrition.ipynb"
PREFIX_A = PREFIX[:-1]
HTML_Name = PREFIX_A.replace("\\", "") + " " # Trailing space is required.
Names_Concat = NB_Convert + HTML_Name + NB_Name
try:
    if(__IPYTHON__):
        get_ipython().system(Names_Concat)
except NameError:
    pass
# Out:
# [NbConvertApp] Converting notebook GS_MLM_CLF_V2.2_IBM_Attrition.ipynb to html_toc
# [NbConvertApp] Writing 1506108 bytes to MLM_V2.2_IBM_Attrition_Iteration_1.html
